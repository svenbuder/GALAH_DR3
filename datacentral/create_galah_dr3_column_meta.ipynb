# %%
import numpy as np
from astropy.table import Table
from astropy.io import fits

# %%
meta = []

# %%
data,header = fits.getdata('../catalogs/GALAH_DR3_main_allspec_v1.fits', header=True, ext=1)
schema = [
    ['*Column Name* | *Description* | *UCD* | *Unit* | *Data Type* | '],
    [':--------------|:--------------|:------------|:------------|:----------|']
]
paper_schema = [
    ['\\begin{table*}'],
    ['\\caption{Table schema of the GALAH DR3 main catalog.} \\label{tab:main_catalog_schema}'],
    ['\\centering'],
    ['\\begin{tabular}{lccc}'],
    ['\\hline'],
    ['Column Name & Units & Description & Data Type \\\\'],
    ['\\hline']
]
for ind,name in enumerate(data.dtype.names):
    if header['TFORM'+str(ind+1)] in ['16A','12A','6A','4A','3A']:
        data_type = 'string'
    elif header['TFORM'+str(ind+1)] in ['K']:
        data_type = 'integer'
    elif header['TFORM'+str(ind+1)] in ['E','D']:
        data_type = 'float'
    else:
        print('HERE',header['TFORM'+str(ind+1)])
    if 'TUNIT'+str(ind+1) in header.keys():
        unit = header['TUNIT'+str(ind+1)]
    else:
        unit=''

    schema.append([name+'|'+header['TCOMM'+str(ind+1)]+'|'+header['TUCD'+str(ind+1)]+'|'+unit+'|'+data_type+'|'])
    paper_schema.append([name.replace('_','\_')+' & '+unit+' & '+(header['TCOMM'+str(ind+1)]).replace('_','\_')+' & '+data_type+' \\\\'])
    
    meta.append(name+'|mainspectable|'+header['TCOMM'+str(ind+1)]+'|'+header['TUCD'+str(ind+1)]+'|'+unit+'|'+data_type)

np.savetxt('../catalogs/schema_GALAH_DR3_main_allspec_v1',np.array(schema),fmt='%s')

paper_schema.append(['\\hline'])
paper_schema.append(['\\end{tabular}'])
paper_schema.append(['\\end{table*}'])
np.savetxt('../dr3_release_paper/tables/main_catalog_schema_raw.tex',np.array(paper_schema),fmt='%s')

# %%
data,header = fits.getdata('../catalogs/GALAH_DR3_main_allstar_v1.fits', header=True, ext=1)
for ind,name in enumerate(data.dtype.names):
    if header['TFORM'+str(ind+1)] in ['16A','12A','6A','4A','3A']:
        data_type = 'string'
    elif header['TFORM'+str(ind+1)] in ['K']:
        data_type = 'integer'
    elif header['TFORM'+str(ind+1)] in ['E','D']:
        data_type = 'float'
    else:
        print('HERE',header['TFORM'+str(ind+1)])
    if 'TUNIT'+str(ind+1) in header.keys():
        unit = header['TUNIT'+str(ind+1)]
    else:
        unit=''

    meta.append(name+'|mainstartable|'+header['TCOMM'+str(ind+1)]+'|'+header['TUCD'+str(ind+1)]+'|'+unit+'|'+data_type)

# %%
data,header = fits.getdata('../catalogs/GALAH_DR3_VAC_ages_v1.fits', header=True, ext=1)
for ind,name in enumerate(data.dtype.names):
    if header['TFORM'+str(ind+1)] in ['16A','12A','6A','4A','3A']:
        data_type = 'string'
    elif header['TFORM'+str(ind+1)] in ['K']:
        data_type = 'integer'
    elif header['TFORM'+str(ind+1)] in ['E','D']:
        data_type = 'float'
    else:
        print('HERE',header['TFORM'+str(ind+1)])
    if 'TUNIT'+str(ind+1) in header.keys():
        unit = header['TUNIT'+str(ind+1)]
    else:
        unit=''

    meta.append(name+'|vacagestable|'+header['TCOMM'+str(ind+1)]+'|'+header['TUCD'+str(ind+1)]+'|'+unit+'|'+data_type)

# %%
data,header = fits.getdata('../catalogs/GALAH_DR3_VAC_dynamics_v1.fits', header=True, ext=1)
for ind,name in enumerate(data.dtype.names):
    if header['TFORM'+str(ind+1)] in ['16A','12A','6A','4A','3A']:
        data_type = 'string'
    elif header['TFORM'+str(ind+1)] in ['K']:
        data_type = 'integer'
    elif header['TFORM'+str(ind+1)] in ['E','D']:
        data_type = 'float'
    else:
        print('HERE',header['TFORM'+str(ind+1)])
    if 'TUNIT'+str(ind+1) in header.keys():
        unit = header['TUNIT'+str(ind+1)]
    else:
        unit=''

    meta.append(name+'|vacdynamicstable|'+header['TCOMM'+str(ind+1)]+'|'+header['TUCD'+str(ind+1)]+'|'+unit+'|'+data_type)

# %%
data,header = fits.getdata('../catalogs/GALAH_DR3_VAC_rv_v1.fits', header=True, ext=1)
for ind,name in enumerate(data.dtype.names):
    if header['TFORM'+str(ind+1)] in ['16A','12A','6A','4A','3A']:
        data_type = 'string'
    elif header['TFORM'+str(ind+1)] in ['K']:
        data_type = 'integer'
    elif header['TFORM'+str(ind+1)] in ['E','D']:
        data_type = 'float'
    else:
        print('HERE',header['TFORM'+str(ind+1)])
    if 'TUNIT'+str(ind+1) in header.keys():
        unit = header['TUNIT'+str(ind+1)]
    else:
        unit=''

    meta.append(name+'|vacrvtable|'+header['TCOMM'+str(ind+1)]+'|'+header['TUCD'+str(ind+1)]+'|'+unit+'|'+data_type)

# %%
np.savetxt('galah_dr3_column_meta.txt',np.array(meta),fmt='%s')
#Table(np.array(meta))

# %%
np.array(meta)
# Out:
# array(['star_id|mainspectable|2MASS identifier|meta.id.cross||string',
#        'sobject_id|mainspectable|GALAH identifier|meta.id||integer',
#        'source_id|mainspectable|Gaia DR2 source_id|meta.id.cross||integer',
#        'survey_name|mainspectable|Name of survey as part of GALAH+DR3|meta.id||string',
#        'field_id|mainspectable|GALAH fco field|meta.id||integer',
#        'flag_repeat|mainspectable|Repeat observation flag, indicating if used for clean catalog|meta.code.qual,stat.fit||integer',
#        'wg4_field|mainspectable|GALAH WG4 field|meta.number||string',
#        'wg4_pipeline|mainspectable|SME pipeline version free/lbol/seis|meta.version||string',
#        'flag_sp|mainspectable|Stellar parameter quality flag|meta.code.qual,stat.fit||integer',
#        'teff|mainspectable|Spectroscopic effective temperature (used for fitting)|phys.temperature.effective|K|float',
#        'e_teff|mainspectable|Uncertainty teff|stat.error;phys.temperature.effective|K|float',
#        'irfm_teff|mainspectable|IRFM temperature (not used for synthesis)|phys.temperature.effective,phot|K|float',
#        'irfm_ebv|mainspectable|E(B-V) used for IRFM teff estimation|phys.absorption.gal|mag|float',
#        'irfm_ebv_ref|mainspectable|Reference irfm_ebv|meta.bib||string',
#        'cov_e_teff|mainspectable|SME covariance fitting uncertainty teff|fit.param;stat.error;phys.temperature.effective|K|float',
#        'init_teff|mainspectable|SME initial teff|fit.param;phys.temperature.effective|K|float',
#        'logg|mainspectable|Surface gravity (not fitted via spectra if wg4_pipeline not free)|phys.gravity|log(cm.s**-2)|float',
#        'e_logg|mainspectable|Uncertainty logg|stat.error;phys.gravity|log(cm.s**-2)|float',
#        'cov_e_logg|mainspectable|MonteCarlo uncertainty logg|fit.param;stat.error;phys.gravity|log(cm.s**-2)|float',
#        'init_logg|mainspectable|SME initial logg|fit.param;phys.gravity|log(cm.s**-2)|float',
#        'fe_h|mainspectable|Fe atomic abundance from Fe lines (final, 1D-NLTE)|phys.abund.Fe||float',
#        'e_fe_h|mainspectable|Uncertainty fe_h|stat.error;phys.abund.Fe||float',
#        'cov_e_fe_h|mainspectable|SME covariance fitting uncertainty fe_h|fit.param;stat.error;phys.abund.Fe||float',
#        'flag_fe_h|mainspectable|Quality flag fe_h|meta.code.qual,stat.fit||integer',
#        'fe_h_atmo|mainspectable|sme.feh from stellar parameter run, fitted from H, Ti, Sc, Fe|stat.fit.param||float',
#        'e_fe_h_atmo|mainspectable|Uncertainty fe_h_atmo|fit.param;phys.abund.Fe||float',
#        'cov_e_fe_h_atmo|mainspectable|SME covariance fitting uncertainty sme.feh|fit.param;stat.error;phys.abund.Fe||float',
#        'init_fe_h_atmo|mainspectable|SME initial sme.feh|fit.param;stat.error;phys.abund.Fe||float',
#        'vmic|mainspectable|Microturbulence velocity (from empirical relation)|phys.veloc.microTurb|km s-1|float',
#        'vbroad|mainspectable|Broadening velocity (fitted sme.vsini with sme.vmac=0)|phys.veloc.rotat|km s-1|float',
#        'e_vbroad|mainspectable|Uncertainty of vbroad|stat.error;phys.veloc.rotat|km s-1|float',
#        'cov_e_vbroad|mainspectable|SME covariance fitting uncertainty sme.vsini|fit.param;stat.error;phys.veloc.rotat|km s-1|float',
#        'init_vbroad|mainspectable|SME initial broadening velocity|fit.param;stat.error;phys.veloc.rotat|km s-1|float',
#        'mass|mainspectable|Stellar parameter fitting product of stellar mass|fit.param;phys.mass|solMass|float',
#        'lbol|mainspectable|Stellar parameter fitting product of bolometric luminosity|fit.param;phys.luminosity|solLum|float',
#        'age|mainspectable|Stellar parameter fitting product of stellar age|fit.param;time.age|Gyr|float',
#        'chi2_sp|mainspectable|Chi2 value of stellar parameter fitting|stat.fit.chi2||float',
#        'alpha_fe|mainspectable|Combined, weighted alpha-process element abundance|phys.abund||float',
#        'e_alpha_fe|mainspectable|Uncertainty of alpha_fe|stat.error;phys.abund||float',
#        'nr_alpha_fe|mainspectable|Bitmask of used measurements for alpha_fe|meta.number||float',
#        'flag_alpha_fe|mainspectable|Quality flag of measurements for alpha_fe|meta.code.qual,stat.fit||integer',
#        'flux_A_Fe|mainspectable|Normalised maximum absorption strength of in iron lines|spectr.line||float',
#        'chi_A_Fe|mainspectable|Chi2 value of iron abundance fitting|stat.fit.chi2||float',
#        'ind_Li6708_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Li6708 with local RV fitted|phys.abund||float',
#        'ind_cov_e_Li6708|mainspectable|SME covariance fitting uncertainty ind_Li6708_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Li6708|mainspectable|Quality flag fit for ind_Li6708_fe|meta.code.qual,stat.fit||integer',
#        'ind_Li6708_NoRV_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Li6708_NoRV with RV fixed|phys.abund||float',
#        'ind_cov_e_Li6708_NoRV|mainspectable|SME covariance fitting uncertainty ind_Li6708_NoRV_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Li6708_NoRV|mainspectable|Quality flag fit for ind_Li6708_NoRV_fe|meta.code.qual,stat.fit||integer',
#        'ind_C6588_fe|mainspectable|Individual uncalibrated measurmenet of line/combo C6588|phys.abund||float',
#        'ind_cov_e_C6588|mainspectable|SME covariance fitting uncertainty ind_C6588_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_C6588|mainspectable|Quality flag fit for ind_C6588_fe|meta.code.qual,stat.fit||integer',
#        'ind_O_fe|mainspectable|Individual uncalibrated measurmenet of line/combo O|phys.abund||float',
#        'ind_cov_e_O|mainspectable|SME covariance fitting uncertainty ind_O_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_O|mainspectable|Quality flag fit for ind_O_fe|meta.code.qual,stat.fit||integer',
#        'ind_Na_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Na|phys.abund||float',
#        'ind_cov_e_Na|mainspectable|SME covariance fitting uncertainty ind_Na_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Na|mainspectable|Quality flag fit for ind_Na_fe|meta.code.qual,stat.fit||integer',
#        'ind_Mg5711_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Mg5711|phys.abund||float',
#        'ind_cov_e_Mg5711|mainspectable|SME covariance fitting uncertainty ind_Mg5711_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Mg5711|mainspectable|Quality flag fit for ind_Mg5711_fe|meta.code.qual,stat.fit||integer',
#        'ind_Al_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Al|phys.abund||float',
#        'ind_cov_e_Al|mainspectable|SME covariance fitting uncertainty ind_Al_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Al|mainspectable|Quality flag fit for ind_Al_fe|meta.code.qual,stat.fit||integer',
#        'ind_Si_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Si|phys.abund||float',
#        'ind_cov_e_Si|mainspectable|SME covariance fitting uncertainty ind_Si_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Si|mainspectable|Quality flag fit for ind_Si_fe|meta.code.qual,stat.fit||integer',
#        'ind_K7699_fe|mainspectable|Individual uncalibrated measurmenet of line/combo K7699|phys.abund||float',
#        'ind_cov_e_K7699|mainspectable|SME covariance fitting uncertainty ind_K7699_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_K7699|mainspectable|Quality flag fit for ind_K7699_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ca_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ca|phys.abund||float',
#        'ind_cov_e_Ca|mainspectable|SME covariance fitting uncertainty ind_Ca_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ca|mainspectable|Quality flag fit for ind_Ca_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sc_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sc|phys.abund||float',
#        'ind_cov_e_Sc|mainspectable|SME covariance fitting uncertainty ind_Sc_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sc|mainspectable|Quality flag fit for ind_Sc_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4758_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4758|phys.abund||float',
#        'ind_cov_e_Ti4758|mainspectable|SME covariance fitting uncertainty ind_Ti4758_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4758|mainspectable|Quality flag fit for ind_Ti4758_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4759_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4759|phys.abund||float',
#        'ind_cov_e_Ti4759|mainspectable|SME covariance fitting uncertainty ind_Ti4759_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4759|mainspectable|Quality flag fit for ind_Ti4759_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4778_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4778|phys.abund||float',
#        'ind_cov_e_Ti4778|mainspectable|SME covariance fitting uncertainty ind_Ti4778_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4778|mainspectable|Quality flag fit for ind_Ti4778_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4782_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4782|phys.abund||float',
#        'ind_cov_e_Ti4782|mainspectable|SME covariance fitting uncertainty ind_Ti4782_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4782|mainspectable|Quality flag fit for ind_Ti4782_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4798_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4798|phys.abund||float',
#        'ind_cov_e_Ti4798|mainspectable|SME covariance fitting uncertainty ind_Ti4798_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4798|mainspectable|Quality flag fit for ind_Ti4798_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4802_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4802|phys.abund||float',
#        'ind_cov_e_Ti4802|mainspectable|SME covariance fitting uncertainty ind_Ti4802_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4802|mainspectable|Quality flag fit for ind_Ti4802_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4820_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4820|phys.abund||float',
#        'ind_cov_e_Ti4820|mainspectable|SME covariance fitting uncertainty ind_Ti4820_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4820|mainspectable|Quality flag fit for ind_Ti4820_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti5689_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti5689|phys.abund||float',
#        'ind_cov_e_Ti5689|mainspectable|SME covariance fitting uncertainty ind_Ti5689_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti5689|mainspectable|Quality flag fit for ind_Ti5689_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti5716_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti5716|phys.abund||float',
#        'ind_cov_e_Ti5716|mainspectable|SME covariance fitting uncertainty ind_Ti5716_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti5716|mainspectable|Quality flag fit for ind_Ti5716_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti5720_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti5720|phys.abund||float',
#        'ind_cov_e_Ti5720|mainspectable|SME covariance fitting uncertainty ind_Ti5720_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti5720|mainspectable|Quality flag fit for ind_Ti5720_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti5739_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti5739|phys.abund||float',
#        'ind_cov_e_Ti5739|mainspectable|SME covariance fitting uncertainty ind_Ti5739_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti5739|mainspectable|Quality flag fit for ind_Ti5739_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti5866_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti5866|phys.abund||float',
#        'ind_cov_e_Ti5866|mainspectable|SME covariance fitting uncertainty ind_Ti5866_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti5866|mainspectable|Quality flag fit for ind_Ti5866_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti6599_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti6599|phys.abund||float',
#        'ind_cov_e_Ti6599|mainspectable|SME covariance fitting uncertainty ind_Ti6599_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti6599|mainspectable|Quality flag fit for ind_Ti6599_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti6717_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti6717|phys.abund||float',
#        'ind_cov_e_Ti6717|mainspectable|SME covariance fitting uncertainty ind_Ti6717_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti6717|mainspectable|Quality flag fit for ind_Ti6717_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti7853_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti7853|phys.abund||float',
#        'ind_cov_e_Ti7853|mainspectable|SME covariance fitting uncertainty ind_Ti7853_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti7853|mainspectable|Quality flag fit for ind_Ti7853_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4720_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4720|phys.abund||float',
#        'ind_cov_e_Ti4720|mainspectable|SME covariance fitting uncertainty ind_Ti4720_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4720|mainspectable|Quality flag fit for ind_Ti4720_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4765_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4765|phys.abund||float',
#        'ind_cov_e_Ti4765|mainspectable|SME covariance fitting uncertainty ind_Ti4765_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4765|mainspectable|Quality flag fit for ind_Ti4765_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4799_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4799|phys.abund||float',
#        'ind_cov_e_Ti4799|mainspectable|SME covariance fitting uncertainty ind_Ti4799_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4799|mainspectable|Quality flag fit for ind_Ti4799_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4849_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4849|phys.abund||float',
#        'ind_cov_e_Ti4849|mainspectable|SME covariance fitting uncertainty ind_Ti4849_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4849|mainspectable|Quality flag fit for ind_Ti4849_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4866_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4866|phys.abund||float',
#        'ind_cov_e_Ti4866|mainspectable|SME covariance fitting uncertainty ind_Ti4866_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4866|mainspectable|Quality flag fit for ind_Ti4866_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ti4874_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ti4874|phys.abund||float',
#        'ind_cov_e_Ti4874|mainspectable|SME covariance fitting uncertainty ind_Ti4874_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ti4874|mainspectable|Quality flag fit for ind_Ti4874_fe|meta.code.qual,stat.fit||integer',
#        'ind_V4832_fe|mainspectable|Individual uncalibrated measurmenet of line/combo V4832|phys.abund||float',
#        'ind_cov_e_V4832|mainspectable|SME covariance fitting uncertainty ind_V4832_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_V4832|mainspectable|Quality flag fit for ind_V4832_fe|meta.code.qual,stat.fit||integer',
#        'ind_V4784_fe|mainspectable|Individual uncalibrated measurmenet of line/combo V4784|phys.abund||float',
#        'ind_cov_e_V4784|mainspectable|SME covariance fitting uncertainty ind_V4784_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_V4784|mainspectable|Quality flag fit for ind_V4784_fe|meta.code.qual,stat.fit||integer',
#        'ind_V4797_fe|mainspectable|Individual uncalibrated measurmenet of line/combo V4797|phys.abund||float',
#        'ind_cov_e_V4797|mainspectable|SME covariance fitting uncertainty ind_V4797_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_V4797|mainspectable|Quality flag fit for ind_V4797_fe|meta.code.qual,stat.fit||integer',
#        'ind_Cr_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Cr|phys.abund||float',
#        'ind_cov_e_Cr|mainspectable|SME covariance fitting uncertainty ind_Cr_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Cr|mainspectable|Quality flag fit for ind_Cr_fe|meta.code.qual,stat.fit||integer',
#        'ind_Mn_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Mn|phys.abund||float',
#        'ind_cov_e_Mn|mainspectable|SME covariance fitting uncertainty ind_Mn_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Mn|mainspectable|Quality flag fit for ind_Mn_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co4781_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co4781|phys.abund||float',
#        'ind_cov_e_Co4781|mainspectable|SME covariance fitting uncertainty ind_Co4781_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co4781|mainspectable|Quality flag fit for ind_Co4781_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co4900_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co4900|phys.abund||float',
#        'ind_cov_e_Co4900|mainspectable|SME covariance fitting uncertainty ind_Co4900_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co4900|mainspectable|Quality flag fit for ind_Co4900_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co5647_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co5647|phys.abund||float',
#        'ind_cov_e_Co5647|mainspectable|SME covariance fitting uncertainty ind_Co5647_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co5647|mainspectable|Quality flag fit for ind_Co5647_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co6490_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co6490|phys.abund||float',
#        'ind_cov_e_Co6490|mainspectable|SME covariance fitting uncertainty ind_Co6490_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co6490|mainspectable|Quality flag fit for ind_Co6490_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co6551_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co6551|phys.abund||float',
#        'ind_cov_e_Co6551|mainspectable|SME covariance fitting uncertainty ind_Co6551_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co6551|mainspectable|Quality flag fit for ind_Co6551_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co6632_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co6632|phys.abund||float',
#        'ind_cov_e_Co6632|mainspectable|SME covariance fitting uncertainty ind_Co6632_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co6632|mainspectable|Quality flag fit for ind_Co6632_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co6679_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co6679|phys.abund||float',
#        'ind_cov_e_Co6679|mainspectable|SME covariance fitting uncertainty ind_Co6679_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co6679|mainspectable|Quality flag fit for ind_Co6679_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co7713_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co7713|phys.abund||float',
#        'ind_cov_e_Co7713|mainspectable|SME covariance fitting uncertainty ind_Co7713_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co7713|mainspectable|Quality flag fit for ind_Co7713_fe|meta.code.qual,stat.fit||integer',
#        'ind_Co7838_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Co7838|phys.abund||float',
#        'ind_cov_e_Co7838|mainspectable|SME covariance fitting uncertainty ind_Co7838_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Co7838|mainspectable|Quality flag fit for ind_Co7838_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ni5847_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ni5847|phys.abund||float',
#        'ind_cov_e_Ni5847|mainspectable|SME covariance fitting uncertainty ind_Ni5847_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ni5847|mainspectable|Quality flag fit for ind_Ni5847_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ni6586_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ni6586|phys.abund||float',
#        'ind_cov_e_Ni6586|mainspectable|SME covariance fitting uncertainty ind_Ni6586_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ni6586|mainspectable|Quality flag fit for ind_Ni6586_fe|meta.code.qual,stat.fit||integer',
#        'ind_Cu5700_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Cu5700|phys.abund||float',
#        'ind_cov_e_Cu5700|mainspectable|SME covariance fitting uncertainty ind_Cu5700_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Cu5700|mainspectable|Quality flag fit for ind_Cu5700_fe|meta.code.qual,stat.fit||integer',
#        'ind_Cu5782_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Cu5782|phys.abund||float',
#        'ind_cov_e_Cu5782|mainspectable|SME covariance fitting uncertainty ind_Cu5782_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Cu5782|mainspectable|Quality flag fit for ind_Cu5782_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zn4722_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zn4722|phys.abund||float',
#        'ind_cov_e_Zn4722|mainspectable|SME covariance fitting uncertainty ind_Zn4722_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zn4722|mainspectable|Quality flag fit for ind_Zn4722_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zn4811_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zn4811|phys.abund||float',
#        'ind_cov_e_Zn4811|mainspectable|SME covariance fitting uncertainty ind_Zn4811_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zn4811|mainspectable|Quality flag fit for ind_Zn4811_fe|meta.code.qual,stat.fit||integer',
#        'ind_Rb7800_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Rb7800|phys.abund||float',
#        'ind_cov_e_Rb7800|mainspectable|SME covariance fitting uncertainty ind_Rb7800_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Rb7800|mainspectable|Quality flag fit for ind_Rb7800_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sr6550_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sr6550|phys.abund||float',
#        'ind_cov_e_Sr6550|mainspectable|SME covariance fitting uncertainty ind_Sr6550_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sr6550|mainspectable|Quality flag fit for ind_Sr6550_fe|meta.code.qual,stat.fit||integer',
#        'ind_Y_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Y|phys.abund||float',
#        'ind_cov_e_Y|mainspectable|SME covariance fitting uncertainty ind_Y_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Y|mainspectable|Quality flag fit for ind_Y_fe|meta.code.qual,stat.fit||integer',
#        'ind_Y4820_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Y4820|phys.abund||float',
#        'ind_cov_e_Y4820|mainspectable|SME covariance fitting uncertainty ind_Y4820_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Y4820|mainspectable|Quality flag fit for ind_Y4820_fe|meta.code.qual,stat.fit||integer',
#        'ind_Y4855_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Y4855|phys.abund||float',
#        'ind_cov_e_Y4855|mainspectable|SME covariance fitting uncertainty ind_Y4855_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Y4855|mainspectable|Quality flag fit for ind_Y4855_fe|meta.code.qual,stat.fit||integer',
#        'ind_Y4884_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Y4884|phys.abund||float',
#        'ind_cov_e_Y4884|mainspectable|SME covariance fitting uncertainty ind_Y4884_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Y4884|mainspectable|Quality flag fit for ind_Y4884_fe|meta.code.qual,stat.fit||integer',
#        'ind_Y5663_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Y5663|phys.abund||float',
#        'ind_cov_e_Y5663|mainspectable|SME covariance fitting uncertainty ind_Y5663_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Y5663|mainspectable|Quality flag fit for ind_Y5663_fe|meta.code.qual,stat.fit||integer',
#        'ind_Y5729_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Y5729|phys.abund||float',
#        'ind_cov_e_Y5729|mainspectable|SME covariance fitting uncertainty ind_Y5729_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Y5729|mainspectable|Quality flag fit for ind_Y5729_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zr4739_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zr4739|phys.abund||float',
#        'ind_cov_e_Zr4739|mainspectable|SME covariance fitting uncertainty ind_Zr4739_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zr4739|mainspectable|Quality flag fit for ind_Zr4739_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zr4772_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zr4772|phys.abund||float',
#        'ind_cov_e_Zr4772|mainspectable|SME covariance fitting uncertainty ind_Zr4772_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zr4772|mainspectable|Quality flag fit for ind_Zr4772_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zr4806_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zr4806|phys.abund||float',
#        'ind_cov_e_Zr4806|mainspectable|SME covariance fitting uncertainty ind_Zr4806_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zr4806|mainspectable|Quality flag fit for ind_Zr4806_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zr4828_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zr4828|phys.abund||float',
#        'ind_cov_e_Zr4828|mainspectable|SME covariance fitting uncertainty ind_Zr4828_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zr4828|mainspectable|Quality flag fit for ind_Zr4828_fe|meta.code.qual,stat.fit||integer',
#        'ind_Zr5681_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Zr5681|phys.abund||float',
#        'ind_cov_e_Zr5681|mainspectable|SME covariance fitting uncertainty ind_Zr5681_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Zr5681|mainspectable|Quality flag fit for ind_Zr5681_fe|meta.code.qual,stat.fit||integer',
#        'ind_Mo5689_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Mo5689|phys.abund||float',
#        'ind_cov_e_Mo5689|mainspectable|SME covariance fitting uncertainty ind_Mo5689_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Mo5689|mainspectable|Quality flag fit for ind_Mo5689_fe|meta.code.qual,stat.fit||integer',
#        'ind_Mo5751_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Mo5751|phys.abund||float',
#        'ind_cov_e_Mo5751|mainspectable|SME covariance fitting uncertainty ind_Mo5751_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Mo5751|mainspectable|Quality flag fit for ind_Mo5751_fe|meta.code.qual,stat.fit||integer',
#        'ind_Mo5858_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Mo5858|phys.abund||float',
#        'ind_cov_e_Mo5858|mainspectable|SME covariance fitting uncertainty ind_Mo5858_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Mo5858|mainspectable|Quality flag fit for ind_Mo5858_fe|meta.code.qual,stat.fit||integer',
#        'ind_Mo6619_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Mo6619|phys.abund||float',
#        'ind_cov_e_Mo6619|mainspectable|SME covariance fitting uncertainty ind_Mo6619_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Mo6619|mainspectable|Quality flag fit for ind_Mo6619_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ru4758_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ru4758|phys.abund||float',
#        'ind_cov_e_Ru4758|mainspectable|SME covariance fitting uncertainty ind_Ru4758_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ru4758|mainspectable|Quality flag fit for ind_Ru4758_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ru4869_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ru4869|phys.abund||float',
#        'ind_cov_e_Ru4869|mainspectable|SME covariance fitting uncertainty ind_Ru4869_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ru4869|mainspectable|Quality flag fit for ind_Ru4869_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ru5699_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ru5699|phys.abund||float',
#        'ind_cov_e_Ru5699|mainspectable|SME covariance fitting uncertainty ind_Ru5699_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ru5699|mainspectable|Quality flag fit for ind_Ru5699_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ba_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ba|phys.abund||float',
#        'ind_cov_e_Ba|mainspectable|SME covariance fitting uncertainty ind_Ba_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ba|mainspectable|Quality flag fit for ind_Ba_fe|meta.code.qual,stat.fit||integer',
#        'ind_La4716_fe|mainspectable|Individual uncalibrated measurmenet of line/combo La4716|phys.abund||float',
#        'ind_cov_e_La4716|mainspectable|SME covariance fitting uncertainty ind_La4716_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_La4716|mainspectable|Quality flag fit for ind_La4716_fe|meta.code.qual,stat.fit||integer',
#        'ind_La4749_fe|mainspectable|Individual uncalibrated measurmenet of line/combo La4749|phys.abund||float',
#        'ind_cov_e_La4749|mainspectable|SME covariance fitting uncertainty ind_La4749_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_La4749|mainspectable|Quality flag fit for ind_La4749_fe|meta.code.qual,stat.fit||integer',
#        'ind_La4804_fe|mainspectable|Individual uncalibrated measurmenet of line/combo La4804|phys.abund||float',
#        'ind_cov_e_La4804|mainspectable|SME covariance fitting uncertainty ind_La4804_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_La4804|mainspectable|Quality flag fit for ind_La4804_fe|meta.code.qual,stat.fit||integer',
#        'ind_La5806_fe|mainspectable|Individual uncalibrated measurmenet of line/combo La5806|phys.abund||float',
#        'ind_cov_e_La5806|mainspectable|SME covariance fitting uncertainty ind_La5806_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_La5806|mainspectable|Quality flag fit for ind_La5806_fe|meta.code.qual,stat.fit||integer',
#        'ind_Ce4774_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Ce4774|phys.abund||float',
#        'ind_cov_e_Ce4774|mainspectable|SME covariance fitting uncertainty ind_Ce4774_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Ce4774|mainspectable|Quality flag fit for ind_Ce4774_fe|meta.code.qual,stat.fit||integer',
#        'ind_Nd4811_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Nd4811|phys.abund||float',
#        'ind_cov_e_Nd4811|mainspectable|SME covariance fitting uncertainty ind_Nd4811_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Nd4811|mainspectable|Quality flag fit for ind_Nd4811_fe|meta.code.qual,stat.fit||integer',
#        'ind_Nd5741_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Nd5741|phys.abund||float',
#        'ind_cov_e_Nd5741|mainspectable|SME covariance fitting uncertainty ind_Nd5741_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Nd5741|mainspectable|Quality flag fit for ind_Nd5741_fe|meta.code.qual,stat.fit||integer',
#        'ind_Nd5770_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Nd5770|phys.abund||float',
#        'ind_cov_e_Nd5770|mainspectable|SME covariance fitting uncertainty ind_Nd5770_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Nd5770|mainspectable|Quality flag fit for ind_Nd5770_fe|meta.code.qual,stat.fit||integer',
#        'ind_Nd5812_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Nd5812|phys.abund||float',
#        'ind_cov_e_Nd5812|mainspectable|SME covariance fitting uncertainty ind_Nd5812_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Nd5812|mainspectable|Quality flag fit for ind_Nd5812_fe|meta.code.qual,stat.fit||integer',
#        'ind_Nd5842_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Nd5842|phys.abund||float',
#        'ind_cov_e_Nd5842|mainspectable|SME covariance fitting uncertainty ind_Nd5842_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Nd5842|mainspectable|Quality flag fit for ind_Nd5842_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sm4720_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sm4720|phys.abund||float',
#        'ind_cov_e_Sm4720|mainspectable|SME covariance fitting uncertainty ind_Sm4720_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sm4720|mainspectable|Quality flag fit for ind_Sm4720_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sm4792_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sm4792|phys.abund||float',
#        'ind_cov_e_Sm4792|mainspectable|SME covariance fitting uncertainty ind_Sm4792_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sm4792|mainspectable|Quality flag fit for ind_Sm4792_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sm4837_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sm4837|phys.abund||float',
#        'ind_cov_e_Sm4837|mainspectable|SME covariance fitting uncertainty ind_Sm4837_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sm4837|mainspectable|Quality flag fit for ind_Sm4837_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sm4848_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sm4848|phys.abund||float',
#        'ind_cov_e_Sm4848|mainspectable|SME covariance fitting uncertainty ind_Sm4848_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sm4848|mainspectable|Quality flag fit for ind_Sm4848_fe|meta.code.qual,stat.fit||integer',
#        'ind_Sm4854_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Sm4854|phys.abund||float',
#        'ind_cov_e_Sm4854|mainspectable|SME covariance fitting uncertainty ind_Sm4854_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Sm4854|mainspectable|Quality flag fit for ind_Sm4854_fe|meta.code.qual,stat.fit||integer',
#        'ind_Eu5819_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Eu5819|phys.abund||float',
#        'ind_cov_e_Eu5819|mainspectable|SME covariance fitting uncertainty ind_Eu5819_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Eu5819|mainspectable|Quality flag fit for ind_Eu5819_fe|meta.code.qual,stat.fit||integer',
#        'ind_Eu6645_fe|mainspectable|Individual uncalibrated measurmenet of line/combo Eu6645|phys.abund||float',
#        'ind_cov_e_Eu6645|mainspectable|SME covariance fitting uncertainty ind_Eu6645_fe|fit.param;stat.error;phys.abund||float',
#        'ind_flag_Eu6645|mainspectable|Quality flag fit for ind_Eu6645_fe|meta.code.qual,stat.fit||integer',
#        'Li_fe|mainspectable|Neutral Li atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Li_fe|mainspectable|Uncertainty Li_fe|stat.error;phys.abund||float',
#        'nr_Li_fe|mainspectable|Bitmask of used Li ind lines|meta.number||integer',
#        'flag_Li_fe|mainspectable|Quality flag of Li_fe|meta.code.qual,stat.fit||integer',
#        'C_fe|mainspectable|Neutral C atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_C_fe|mainspectable|Uncertainty C_fe|stat.error;phys.abund||float',
#        'nr_C_fe|mainspectable|Bitmask of used C ind lines|meta.number||integer',
#        'flag_C_fe|mainspectable|Quality flag of C_fe|meta.code.qual,stat.fit||integer',
#        'O_fe|mainspectable|Neutral O atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_O_fe|mainspectable|Uncertainty O_fe|stat.error;phys.abund||float',
#        'nr_O_fe|mainspectable|Bitmask of used O ind lines|meta.number||integer',
#        'flag_O_fe|mainspectable|Quality flag of O_fe|meta.code.qual,stat.fit||integer',
#        'Na_fe|mainspectable|Neutral Na atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Na_fe|mainspectable|Uncertainty Na_fe|stat.error;phys.abund||float',
#        'nr_Na_fe|mainspectable|Bitmask of used Na ind lines|meta.number||integer',
#        'flag_Na_fe|mainspectable|Quality flag of Na_fe|meta.code.qual,stat.fit||integer',
#        'Mg_fe|mainspectable|Neutral Mg atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Mg_fe|mainspectable|Uncertainty Mg_fe|stat.error;phys.abund||float',
#        'nr_Mg_fe|mainspectable|Bitmask of used Mg ind lines|meta.number||integer',
#        'flag_Mg_fe|mainspectable|Quality flag of Mg_fe|meta.code.qual,stat.fit||integer',
#        'Al_fe|mainspectable|Neutral Al atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Al_fe|mainspectable|Uncertainty Al_fe|stat.error;phys.abund||float',
#        'nr_Al_fe|mainspectable|Bitmask of used Al ind lines|meta.number||integer',
#        'flag_Al_fe|mainspectable|Quality flag of Al_fe|meta.code.qual,stat.fit||integer',
#        'Si_fe|mainspectable|Neutral Si atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Si_fe|mainspectable|Uncertainty Si_fe|stat.error;phys.abund||float',
#        'nr_Si_fe|mainspectable|Bitmask of used Si ind lines|meta.number||integer',
#        'flag_Si_fe|mainspectable|Quality flag of Si_fe|meta.code.qual,stat.fit||integer',
#        'K_fe|mainspectable|Neutral K atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_K_fe|mainspectable|Uncertainty K_fe|stat.error;phys.abund||float',
#        'nr_K_fe|mainspectable|Bitmask of used K ind lines|meta.number||integer',
#        'flag_K_fe|mainspectable|Quality flag of K_fe|meta.code.qual,stat.fit||integer',
#        'Ca_fe|mainspectable|Neutral Ca atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Ca_fe|mainspectable|Uncertainty Ca_fe|stat.error;phys.abund||float',
#        'nr_Ca_fe|mainspectable|Bitmask of used Ca ind lines|meta.number||integer',
#        'flag_Ca_fe|mainspectable|Quality flag of Ca_fe|meta.code.qual,stat.fit||integer',
#        'Sc_fe|mainspectable|Neutral Sc atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Sc_fe|mainspectable|Uncertainty Sc_fe|stat.error;phys.abund||float',
#        'nr_Sc_fe|mainspectable|Bitmask of used Sc ind lines|meta.number||integer',
#        'flag_Sc_fe|mainspectable|Quality flag of Sc_fe|meta.code.qual,stat.fit||integer',
#        'Sc2_fe|mainspectable|Single-ionised Sc2 atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Sc2_fe|mainspectable|Uncertainty Sc2_fe|stat.error;phys.abund||float',
#        'nr_Sc2_fe|mainspectable|Bitmask of used Sc2 ind lines|meta.number||integer',
#        'flag_Sc2_fe|mainspectable|Quality flag of Sc2_fe|meta.code.qual,stat.fit||integer',
#        'Ti_fe|mainspectable|Neutral Ti atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Ti_fe|mainspectable|Uncertainty Ti_fe|stat.error;phys.abund||float',
#        'nr_Ti_fe|mainspectable|Bitmask of used Ti ind lines|meta.number||integer',
#        'flag_Ti_fe|mainspectable|Quality flag of Ti_fe|meta.code.qual,stat.fit||integer',
#        'Ti2_fe|mainspectable|Single-ionised Ti2 atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Ti2_fe|mainspectable|Uncertainty Ti2_fe|stat.error;phys.abund||float',
#        'nr_Ti2_fe|mainspectable|Bitmask of used Ti2 ind lines|meta.number||integer',
#        'flag_Ti2_fe|mainspectable|Quality flag of Ti2_fe|meta.code.qual,stat.fit||integer',
#        'V_fe|mainspectable|Neutral V atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_V_fe|mainspectable|Uncertainty V_fe|stat.error;phys.abund||float',
#        'nr_V_fe|mainspectable|Bitmask of used V ind lines|meta.number||integer',
#        'flag_V_fe|mainspectable|Quality flag of V_fe|meta.code.qual,stat.fit||integer',
#        'Cr_fe|mainspectable|Neutral Cr atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Cr_fe|mainspectable|Uncertainty Cr_fe|stat.error;phys.abund||float',
#        'nr_Cr_fe|mainspectable|Bitmask of used Cr ind lines|meta.number||integer',
#        'flag_Cr_fe|mainspectable|Quality flag of Cr_fe|meta.code.qual,stat.fit||integer',
#        'Cr2_fe|mainspectable|Single-ionised Cr2 atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Cr2_fe|mainspectable|Uncertainty Cr2_fe|stat.error;phys.abund||float',
#        'nr_Cr2_fe|mainspectable|Bitmask of used Cr2 ind lines|meta.number||integer',
#        'flag_Cr2_fe|mainspectable|Quality flag of Cr2_fe|meta.code.qual,stat.fit||integer',
#        'Mn_fe|mainspectable|Neutral Mn atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Mn_fe|mainspectable|Uncertainty Mn_fe|stat.error;phys.abund||float',
#        'nr_Mn_fe|mainspectable|Bitmask of used Mn ind lines|meta.number||integer',
#        'flag_Mn_fe|mainspectable|Quality flag of Mn_fe|meta.code.qual,stat.fit||integer',
#        'Co_fe|mainspectable|Neutral Co atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Co_fe|mainspectable|Uncertainty Co_fe|stat.error;phys.abund||float',
#        'nr_Co_fe|mainspectable|Bitmask of used Co ind lines|meta.number||integer',
#        'flag_Co_fe|mainspectable|Quality flag of Co_fe|meta.code.qual,stat.fit||integer',
#        'Ni_fe|mainspectable|Neutral Ni atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Ni_fe|mainspectable|Uncertainty Ni_fe|stat.error;phys.abund||float',
#        'nr_Ni_fe|mainspectable|Bitmask of used Ni ind lines|meta.number||integer',
#        'flag_Ni_fe|mainspectable|Quality flag of Ni_fe|meta.code.qual,stat.fit||integer',
#        'Cu_fe|mainspectable|Neutral Cu atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Cu_fe|mainspectable|Uncertainty Cu_fe|stat.error;phys.abund||float',
#        'nr_Cu_fe|mainspectable|Bitmask of used Cu ind lines|meta.number||integer',
#        'flag_Cu_fe|mainspectable|Quality flag of Cu_fe|meta.code.qual,stat.fit||integer',
#        'Zn_fe|mainspectable|Neutral Zn atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Zn_fe|mainspectable|Uncertainty Zn_fe|stat.error;phys.abund||float',
#        'nr_Zn_fe|mainspectable|Bitmask of used Zn ind lines|meta.number||integer',
#        'flag_Zn_fe|mainspectable|Quality flag of Zn_fe|meta.code.qual,stat.fit||integer',
#        'Rb_fe|mainspectable|Neutral Rb atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Rb_fe|mainspectable|Uncertainty Rb_fe|stat.error;phys.abund||float',
#        'nr_Rb_fe|mainspectable|Bitmask of used Rb ind lines|meta.number||integer',
#        'flag_Rb_fe|mainspectable|Quality flag of Rb_fe|meta.code.qual,stat.fit||integer',
#        'Sr_fe|mainspectable|Neutral Sr atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Sr_fe|mainspectable|Uncertainty Sr_fe|stat.error;phys.abund||float',
#        'nr_Sr_fe|mainspectable|Bitmask of used Sr ind lines|meta.number||integer',
#        'flag_Sr_fe|mainspectable|Quality flag of Sr_fe|meta.code.qual,stat.fit||integer',
#        'Y_fe|mainspectable|Neutral Y atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Y_fe|mainspectable|Uncertainty Y_fe|stat.error;phys.abund||float',
#        'nr_Y_fe|mainspectable|Bitmask of used Y ind lines|meta.number||integer',
#        'flag_Y_fe|mainspectable|Quality flag of Y_fe|meta.code.qual,stat.fit||integer',
#        'Zr_fe|mainspectable|Neutral Zr atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Zr_fe|mainspectable|Uncertainty Zr_fe|stat.error;phys.abund||float',
#        'nr_Zr_fe|mainspectable|Bitmask of used Zr ind lines|meta.number||integer',
#        'flag_Zr_fe|mainspectable|Quality flag of Zr_fe|meta.code.qual,stat.fit||integer',
#        'Mo_fe|mainspectable|Neutral Mo atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Mo_fe|mainspectable|Uncertainty Mo_fe|stat.error;phys.abund||float',
#        'nr_Mo_fe|mainspectable|Bitmask of used Mo ind lines|meta.number||integer',
#        'flag_Mo_fe|mainspectable|Quality flag of Mo_fe|meta.code.qual,stat.fit||integer',
#        'Ru_fe|mainspectable|Neutral Ru atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Ru_fe|mainspectable|Uncertainty Ru_fe|stat.error;phys.abund||float',
#        'nr_Ru_fe|mainspectable|Bitmask of used Ru ind lines|meta.number||integer',
#        'flag_Ru_fe|mainspectable|Quality flag of Ru_fe|meta.code.qual,stat.fit||integer',
#        'Ba_fe|mainspectable|Single-ionised Ba atomic abundance (final, 1D-NLTE)|phys.abund||float',
#        'e_Ba_fe|mainspectable|Uncertainty Ba_fe|stat.error;phys.abund||float',
#        'nr_Ba_fe|mainspectable|Bitmask of used Ba ind lines|meta.number||integer',
#        'flag_Ba_fe|mainspectable|Quality flag of Ba_fe|meta.code.qual,stat.fit||integer',
#        'La_fe|mainspectable|Single-ionised La atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_La_fe|mainspectable|Uncertainty La_fe|stat.error;phys.abund||float',
#        'nr_La_fe|mainspectable|Bitmask of used La ind lines|meta.number||integer',
#        'flag_La_fe|mainspectable|Quality flag of La_fe|meta.code.qual,stat.fit||integer',
#        'Ce_fe|mainspectable|Single-ionised Ce atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Ce_fe|mainspectable|Uncertainty Ce_fe|stat.error;phys.abund||float',
#        'nr_Ce_fe|mainspectable|Bitmask of used Ce ind lines|meta.number||integer',
#        'flag_Ce_fe|mainspectable|Quality flag of Ce_fe|meta.code.qual,stat.fit||integer',
#        'Nd_fe|mainspectable|Single-ionised Nd atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Nd_fe|mainspectable|Uncertainty Nd_fe|stat.error;phys.abund||float',
#        'nr_Nd_fe|mainspectable|Bitmask of used Nd ind lines|meta.number||integer',
#        'flag_Nd_fe|mainspectable|Quality flag of Nd_fe|meta.code.qual,stat.fit||integer',
#        'Sm_fe|mainspectable|Single-ionised Sm atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Sm_fe|mainspectable|Uncertainty Sm_fe|stat.error;phys.abund||float',
#        'nr_Sm_fe|mainspectable|Bitmask of used Sm ind lines|meta.number||integer',
#        'flag_Sm_fe|mainspectable|Quality flag of Sm_fe|meta.code.qual,stat.fit||integer',
#        'Eu_fe|mainspectable|Single-ionised Eu atomic abundance (final, 1D-LTE)|phys.abund||float',
#        'e_Eu_fe|mainspectable|Uncertainty Eu_fe|stat.error;phys.abund||float',
#        'nr_Eu_fe|mainspectable|Bitmask of used Eu ind lines|meta.number||integer',
#        'flag_Eu_fe|mainspectable|Quality flag of Eu_fe|meta.code.qual,stat.fit||integer',
#        'ra|mainspectable|propagated from Gaia DR2|pos.eq.ra;meta.main|deg|float',
#        'ra_error|mainspectable|propagated from Gaia DR2|stat.error;pos.eq.ra|mas|float',
#        'dec|mainspectable|propagated from Gaia DR2|pos.eq.dec;meta.main|deg|float',
#        'dec_error|mainspectable|propagated from Gaia DR2|stat.error;pos.eq.dec|mas|float',
#        'l|mainspectable|propagated from Gaia DR2|pos.galactic.lon|deg|float',
#        'b|mainspectable|propagated from Gaia DR2|pos.galactic.lat|deg|float',
#        'parallax|mainspectable|propagated from Gaia DR2|pos.parallax|mas|float',
#        'parallax_error|mainspectable|propagated from Gaia DR2|stat.error;pos.parallax|mas|float',
#        'r_est|mainspectable|propagated from 2018AJ....156...58B|pos.distance|pc|float',
#        'r_lo|mainspectable|propagated from 2018AJ....156...58B|stat.error;stat.min;pos.distance|pc|float',
#        'r_hi|mainspectable|propagated from 2018AJ....156...58B|stat.error;stat.max;pos.distance|pc|float',
# ...
#        'e16_teff_bstep|vacagestable|16 percentile value for teff_bstep|stat.error;stat.min;phys.temperature.effective||float',
#        'e84_teff_bstep|vacagestable|84 percentile value for teff_bstep|stat.error;stat.max;phys.temperature.effective||float',
#        'logg_bstep|vacagestable|Surface gravity BSTEP-Mod.|phys.gravity||float',
#        'e_logg_bstep|vacagestable|1-sigma uncertainty of logg_bstep|stat.error;stat.stdev;phys.gravity||float',
#        'e16_logg_bstep|vacagestable|16 percentile value for logg_bstep|stat.error;stat.min;phys.gravity||float',
#        'e84_logg_bstep|vacagestable|84 percentile value for logg_bstep|stat.error;stat.max;phys.gravity||float',
#        'meh_act_bstep|vacagestable|Surface effective [M/H] BSTEP-Mod.|phys.abund||float',
#        'e_meh_act_bstep|vacagestable|1-sigma uncertainty of meh_act_bstep|stat.error;stat.stdev;phys.abund||float',
#        'e16_meh_act_bstep|vacagestable|16 percentile value for meh_act_bstep|stat.error;stat.min;phys.abund||float',
#        'e84_meh_act_bstep|vacagestable|84 percentile value for meh_act_bstep|stat.error;stat.max;phys.abund||float',
#        'meh_ini_bstep|vacagestable|Intial effective metallicity [M/H] from isochrones BSTEP-Mod.|phys.abund||float',
#        'e_meh_ini_bstep|vacagestable|1-sigma uncertainty of meh_ini_bstep|stat.error;stat.stdev;phys.abund||float',
#        'e16_meh_ini_bstep|vacagestable|16 percentile value for meh_ini_bstep|stat.error;stat.min;phys.abund||float',
#        'e84_meh_ini_bstep|vacagestable|84 percentile value for meh_ini_bstep|stat.error;stat.max;phys.abund||float',
#        'log_lum_bstep|vacagestable|log(Luminosity L/L_sun)|phys.luminosity||float',
#        'e_log_lum_bstep|vacagestable|1-sigma uncertainty of log_lum_bstep|stat.error;stat.stdev;phys.luminosity||float',
#        'e16_log_lum_bstep|vacagestable|16 percentile value for log_lum_bstep|stat.error;stat.min;phys.luminosity||float',
#        'e84_log_lum_bstep|vacagestable|84 percentile value for log_lum_bstep|stat.error;stat.max;phys.luminosity||float',
#        'sobject_id|vacdynamicstable|GALAH identifier|meta.id||integer',
#        'X_XYZ|vacdynamicstable|Best-value heliocentric Galactic rectangular x-coordinate|pos.cartesian.x;pos.heliocentric|kpc|float',
#        'Y_XYZ|vacdynamicstable|Best-value heliocentric Galactic rectangular y-coordinate|pos.cartesian.y;pos.heliocentric|kpc|float',
#        'Z_XYZ|vacdynamicstable|Best-value heliocentric Galactic rectangular z-coordinate|pos.cartesian.z;pos.heliocentric|kpc|float',
#        'U_UVW|vacdynamicstable|Best-value heliocentric Galactic rectangular x-velocity|phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'V_UVW|vacdynamicstable|Best-value heliocentric Galactic rectangular y-velocity|phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'W_UVW|vacdynamicstable|Best-value heliocentric Galactic rectangular z-velocity|phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'R_Rzphi|vacdynamicstable|Best-value Galactocentric Radius|pos.galactocentric|kpc|float',
#        'z_Rzphi|vacdynamicstable|Best-value Galactocentric height|pos.galactocentric|kpc|float',
#        'phi_Rzphi|vacdynamicstable|Best-value Galactocentric azimuth|pos.galactocentric|rad|float',
#        'vR_Rzphi|vacdynamicstable|Best-value Galactocentric radial velocity|phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vz_Rzphi|vacdynamicstable|Best-value Galactocentric vertical velocity|phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vphi_Rzphi|vacdynamicstable|Best-value Galactocentric azimuthal velocity|phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vT_Rzphi|vacdynamicstable|Best-value Galactocentric tangential velocity|phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'J_R|vacdynamicstable|Best-value radial action|src.orbital|km kpc s-1|float',
#        'L_Z|vacdynamicstable|Best-value azimuthal action / angular momentum|src.orbital;phys.angMomentum|km kpc s-1|float',
#        'J_Z|vacdynamicstable|Best-value vertical action|src.orbital|km kpc s-1|float',
#        'Omegar|vacdynamicstable|Best-value radial orbit frequency|src.orbital|Gyr-1|float',
#        'Omegaphi|vacdynamicstable|Best-value azimuthal orbit frequency|src.orbital|Gyr-1|float',
#        'Omegaz|vacdynamicstable|Best-value vertical orbit frequency|src.orbital|Gyr-1|float',
#        'ecc|vacdynamicstable|Best-value orbit eccentricity|src.orbital.eccentricity||float',
#        'zmax|vacdynamicstable|Best-value maximum Galactocentric height|src.orbital|kpc|float',
#        'R_peri|vacdynamicstable|Best-value Galactocentric pericenter radius|src.orbital|kpc|float',
#        'R_ap|vacdynamicstable|Best-value Galactocentric apocenter radius|src.orbital|kpc|float',
#        'Energy|vacdynamicstable|Best-value orbit energy|src.orbital;phys.energy|km-2 s-2|float',
#        'X_XYZ_5|vacdynamicstable|5th Percentile MC heliocentric Galactic rectangular x-coordinate|stat.error;stat.min;pos.cartesian.x;pos.heliocentric|kpc|float',
#        'X_XYZ_50|vacdynamicstable|50th Percentile MC heliocentric Galactic rectangular x-coordinate|stat.error;stat.median;pos.cartesian.x;pos.heliocentric|kpc|float',
#        'X_XYZ_95|vacdynamicstable|95th Percentile MC heliocentric Galactic rectangular x-coordinate|stat.error;stat.max;pos.cartesian.x;pos.heliocentric|kpc|float',
#        'Y_XYZ_5|vacdynamicstable|5th Percentile MC heliocentric Galactic rectangular y-coordinate|stat.error;stat.min;pos.cartesian.y;pos.heliocentric|kpc|float',
#        'Y_XYZ_50|vacdynamicstable|50th Percentile MC heliocentric Galactic rectangular y-coordinate|stat.error;stat.median;pos.cartesian.y;pos.heliocentric|kpc|float',
#        'Y_XYZ_95|vacdynamicstable|95th Percentile MC heliocentric Galactic rectangular y-coordinate|stat.error;stat.max;pos.cartesian.y;pos.heliocentric|kpc|float',
#        'Z_XYZ_5|vacdynamicstable|5th Percentile MC heliocentric Galactic rectangular z-coordinate|stat.error;stat.min;pos.cartesian.z;pos.heliocentric|kpc|float',
#        'Z_XYZ_50|vacdynamicstable|50th Percentile MC heliocentric Galactic rectangular z-coordinate|stat.error;stat.median;pos.cartesian.z;pos.heliocentric|kpc|float',
#        'Z_XYZ_95|vacdynamicstable|95th Percentile MC heliocentric Galactic rectangular z-coordinate|stat.error;stat.max;pos.cartesian.z;pos.heliocentric|kpc|float',
#        'U_UVW_5|vacdynamicstable|5th Percentile MC heliocentric Galactic rectangular x-velocity|stat.error;stat.min;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'U_UVW_50|vacdynamicstable|50th Percentile MC heliocentric Galactic rectangular x-velocity|stat.error;stat.median;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'U_UVW_95|vacdynamicstable|95th Percentile MC heliocentric Galactic rectangular x-velocity|stat.error;stat.max;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'V_UVW_5|vacdynamicstable|5th Percentile MC heliocentric Galactic rectangular y-velocity|stat.error;stat.min;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'V_UVW_50|vacdynamicstable|50th Percentile MC heliocentric Galactic rectangular y-velocity|stat.error;stat.median;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'V_UVW_95|vacdynamicstable|95th Percentile MC heliocentric Galactic rectangular y-velocity|stat.error;stat.max;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'W_UVW_5|vacdynamicstable|5th Percentile MC heliocentric Galactic rectangular z-velocity|stat.error;stat.min;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'W_UVW_50|vacdynamicstable|50th Percentile MC heliocentric Galactic rectangular z-velocity|stat.error;stat.median;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'W_UVW_95|vacdynamicstable|95th Percentile MC heliocentric Galactic rectangular z-velocity|stat.error;stat.max;phys.vel.orbital;pos.heliocentric|km s-1|float',
#        'R_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric Radius|stat.error;stat.min;pos.galactocentric|kpc|float',
#        'R_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric Radius|stat.error;stat.median;pos.galactocentric|kpc|float',
#        'R_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric Radius|stat.error;stat.max;pos.galactocentric|kpc|float',
#        'z_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric height|stat.error;stat.min;pos.galactocentric|kpc|float',
#        'z_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric height|stat.error;stat.median;pos.galactocentric|kpc|float',
#        'z_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric height|stat.error;stat.max;pos.galactocentric|kpc|float',
#        'phi_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric azimuth|stat.error;stat.min;pos.galactocentric|rad|float',
#        'phi_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric azimuth|stat.error;stat.median;pos.galactocentric|rad|float',
#        'phi_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric azimuth|stat.error;stat.max;pos.galactocentric|rad|float',
#        'vR_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric radial velocity|stat.error;stat.min;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vR_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric radial velocity|stat.error;stat.median;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vR_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric radial velocity|stat.error;stat.max;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vz_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric vertical velocity|stat.error;stat.min;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vz_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric vertical velocity|stat.error;stat.median;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vz_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric vertical velocity|stat.error;stat.max;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vphi_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric azimuthal velocity|stat.error;stat.min;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vphi_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric azimuthal velocity|stat.error;stat.median;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vphi_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric azimuthal velocity|stat.error;stat.max;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vT_Rzphi_5|vacdynamicstable|5th Percentile MC Galactocentric tangential velocity|stat.error;stat.min;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vT_Rzphi_50|vacdynamicstable|50th Percentile MC Galactocentric tangential velocity|stat.error;stat.median;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'vT_Rzphi_95|vacdynamicstable|95th Percentile MC Galactocentric tangential velocity|stat.error;stat.max;phys.vel.orbital;pos.galactocentric|km s-1|float',
#        'J_R_5|vacdynamicstable|5th Percentile MC radial action|stat.error;stat.min;src.orbital|km kpc s-1|float',
#        'J_R_50|vacdynamicstable|50th Percentile MC radial action|stat.error;stat.median;src.orbital|km kpc s-1|float',
#        'J_R_95|vacdynamicstable|95th Percentile MC radial action|stat.error;stat.max;src.orbital|km kpc s-1|float',
#        'L_Z_5|vacdynamicstable|5th Percentile MC azimuthal action / angular momentum|stat.error;stat.min;src.orbital;phys.angMomentum|km kpc s-1|float',
#        'L_Z_50|vacdynamicstable|50th Percentile MC azimuthal action / angular momentum|stat.error;stat.median;src.orbital;phys.angMomentum|km kpc s-1|float',
#        'L_Z_95|vacdynamicstable|95th Percentile MC azimuthal action / angular momentum|stat.error;stat.max;src.orbital;phys.angMomentum|km kpc s-1|float',
#        'J_Z_5|vacdynamicstable|5th Percentile MC vertical action|stat.error;stat.min;src.orbital|km kpc s-1|float',
#        'J_Z_50|vacdynamicstable|50th Percentile MC vertical action|stat.error;stat.median;src.orbital|km kpc s-1|float',
#        'J_Z_95|vacdynamicstable|95th Percentile MC vertical action|stat.error;stat.max;src.orbital|km kpc s-1|float',
#        'Omegar_5|vacdynamicstable|5th Percentile MC radial orbit frequency|stat.error;stat.min;src.orbital|Gyr-1|float',
#        'Omegar_50|vacdynamicstable|50th Percentile MC radial orbit frequency|stat.error;stat.median;src.orbital|Gyr-1|float',
#        'Omegar_95|vacdynamicstable|95th Percentile MC radial orbit frequency|stat.error;stat.max;src.orbital|Gyr-1|float',
#        'Omegaphi_5|vacdynamicstable|5th Percentile MC azimuthal orbit frequency|stat.error;stat.min;src.orbital|Gyr-1|float',
#        'Omegaphi_50|vacdynamicstable|50th Percentile MC azimuthal orbit frequency|stat.error;stat.median;src.orbital|Gyr-1|float',
#        'Omegaphi_95|vacdynamicstable|95th Percentile MC azimuthal orbit frequency|stat.error;stat.max;src.orbital|Gyr-1|float',
#        'Omegaz_5|vacdynamicstable|5th Percentile MC vertical orbit frequency|stat.error;stat.min;src.orbital|Gyr-1|float',
#        'Omegaz_50|vacdynamicstable|50th Percentile MC vertical orbit frequency|stat.error;stat.median;src.orbital|Gyr-1|float',
#        'Omegaz_95|vacdynamicstable|95th Percentile MC vertical orbit frequency|stat.error;stat.max;src.orbital|Gyr-1|float',
#        'ecc_5|vacdynamicstable|5th Percentile MC orbit eccentricity|stat.error;stat.min;src.orbital.eccentricity||float',
#        'ecc_50|vacdynamicstable|50th Percentile MC orbit eccentricity|stat.error;stat.median;src.orbital.eccentricity||float',
#        'ecc_95|vacdynamicstable|95th Percentile MC orbit eccentricity|stat.error;stat.max;src.orbital.eccentricity||float',
#        'zmax_5|vacdynamicstable|5th Percentile MC maximum Galactocentric height|stat.error;stat.min;src.orbital|kpc|float',
#        'zmax_50|vacdynamicstable|50th Percentile MC maximum Galactocentric height|stat.error;stat.median;src.orbital|kpc|float',
#        'zmax_95|vacdynamicstable|95th Percentile MC maximum Galactocentric height|stat.error;stat.max;src.orbital|kpc|float',
#        'R_peri_5|vacdynamicstable|5th Percentile MC Galactocentric pericenter radius|stat.error;stat.min;src.orbital|kpc|float',
#        'R_peri_50|vacdynamicstable|50th Percentile MC Galactocentric pericenter radius|stat.error;stat.median;src.orbital|kpc|float',
#        'R_peri_95|vacdynamicstable|95th Percentile MC Galactocentric pericenter radius|stat.error;stat.max;src.orbital|kpc|float',
#        'R_ap_5|vacdynamicstable|5th Percentile MC Galactocentric apocenter radius|stat.error;stat.min;src.orbital|kpc|float',
#        'R_ap_50|vacdynamicstable|50th Percentile MC Galactocentric apocenter radius|stat.error;stat.median;src.orbital|kpc|float',
#        'R_ap_95|vacdynamicstable|95th Percentile MC Galactocentric apocenter radius|stat.error;stat.max;src.orbital|kpc|float',
#        'Energy_5|vacdynamicstable|5th Percentile MC orbit energy|stat.error;stat.min;src.orbital;phys.energy|km-2 s-2|float',
#        'Energy_50|vacdynamicstable|50th Percentile MC orbit energy|stat.error;stat.median;src.orbital;phys.energy|km-2 s-2|float',
#        'Energy_95|vacdynamicstable|95th Percentile MC orbit energy|stat.error;stat.max;src.orbital;phys.energy|km-2 s-2|float',
#        'sobject_id|vacrvtable|GALAH identifier|meta.id||integer',
#        'vbaryorig|vacrvtable|Original barycentric correction used|obs.param|km s-1|float',
#        'vbarycorr|vacrvtable|Correct barycentric correction|obs.param|km s-1|float',
#        'rv_obst|vacrvtable|Radial Velocity with grav. redshift correction|spect.dopplerVeloc.opt|km s-1|float',
#        'e_rv_obst|vacrvtable|Uncertainty of rv_obst|stat.error;spect.dopplerVeloc.opt|km s-1|float',
#        'rv_nogr_obst|vacrvtable|Radial Velocity without grav. redshift correction|spect.dopplerVeloc.opt|km s-1|float',
#        'e_rv_nogr_obst|vacrvtable|Uncertainty of rv_nogr_obst|stat.error;spect.dopplerVeloc.opt|km s-1|float',
#        'MJD_local|vacrvtable|Modified Julian Date, Middle of Exposure|time.epoch|d|float',
#        'heliocentricJD|vacrvtable|Heliocentric Julian Date|time.epoch|d|float'],
#       dtype='<U159')
